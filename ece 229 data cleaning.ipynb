# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('/Users/zhenweiliu/Desktop/ECE229-Group6/good_reads_final.csv')
df.head()
# Out:
#    author_average_rating author_gender                          author_genres  \
# 0                   4.01        female                    historical-fiction,
# 1                   4.15          male  literature-fiction,mystery-thrillers,
# 2                   4.00        female                               romance,
# 3                   3.88          male                        fiction,memoir,
# 4                   4.10        female                   young-adult,fantasy,
#
#    author_id            author_name                           author_page_url  \
# 0      74489    Victoria Thompson\n      /author/show/74489.Victoria_Thompson
# 1     706255        Stieg Larsson\n         /author/show/706255.Stieg_Larsson
# 2    5618190  Mimi Jean Pamfiloff\n  /author/show/5618190.Mimi_Jean_Pamfiloff
# 3      37871          José Donoso\n             /author/show/37871.Jos_Donoso
# 4      36122    Patricia C. Wrede\n       /author/show/36122.Patricia_C_Wrede
#
# ...

# %%
df.shape
# Out:
# (22891, 20)

# %%
#########################
#drop duplicate book names#
#############################

# %%
df['book_title'].is_unique
# Out:
# False

# %%
df.drop_duplicates(subset=['book_title'], keep='first',inplace=True)

# %%
df.shape
# Out:
# (16350, 20)

# %%
df['book_title'].is_unique
# Out:
# True

# %%
###########################
# delete_non_int in book ids
############################

# %%
df.dtypes
# Out:
# author_average_rating    float64
# author_gender             object
# author_genres             object
# author_id                  int64
# author_name               object
# author_page_url           object
# author_rating_count        int64
# author_review_count        int64
# birthplace                object
# book_average_rating      float64
# book_fullurl              object
# book_id                   object
# book_title                object
# genre_1                   object
# genre_2                   object
# num_ratings                int64
# num_reviews                int64
# pages                     object
# publish_date              object
# score                      int64
# dtype: object

# %%
df = df.reset_index()
del df['index']
#del df['level_0']
df.head(2201)
# Out:
#       author_average_rating author_gender  \
# 0                      4.01        female
# 1                      4.15          male
# 2                      4.00        female
# 3                      3.88          male
# 4                      4.10        female
# ...                     ...           ...
# 2196                   4.60          male
# 2197                   3.76          male
# 2198                   4.20          male
# 2199                   3.94          male
# 2200                   4.04          male
#
#                                   author_genres  author_id  \
# 0                           historical-fiction,      74489
# 1         literature-fiction,mystery-thrillers,     706255
# 2                                      romance,    5618190
# 3                               fiction,memoir,      37871
# 4                          young-adult,fantasy,      36122
# ...                                         ...        ...
# ...

# %%
(df['book_id'][2197]).isdigit()
# Out:
# True

# %%
df.shape
# Out:
# (16350, 20)

# %%
id_index_list_to_drop = []
for i in range(len(df['book_id'])):
    if df['book_id'][i].isdigit() == False:
        id_index_list_to_drop.append(df.index[i])
        #print(df.index[i])
        #df.drop(df.index[i])

# %%
df = df.drop(labels=id_index_list_to_drop, axis=0)

# %%
df.shape
# Out:
# (16096, 20)

# %%
df.head(2201)
# Out:
#       author_average_rating author_gender  \
# 0                      4.01        female
# 1                      4.15          male
# 2                      4.00        female
# 3                      3.88          male
# 4                      4.10        female
# ...                     ...           ...
# 2197                   3.76          male
# 2199                   3.94          male
# 2200                   4.04          male
# 2216                   4.21          male
# 2224                   3.87          male
#
#                                   author_genres  author_id  \
# 0                           historical-fiction,      74489
# 1         literature-fiction,mystery-thrillers,     706255
# 2                                      romance,    5618190
# 3                               fiction,memoir,      37871
# 4                          young-adult,fantasy,      36122
# ...                                         ...        ...
# ...

# %%
df = df.reset_index()
del df['index']
#del df['level_0']
df.head(135)
# Out:
#      author_average_rating author_gender  \
# 0                     4.01        female
# 1                     4.15          male
# 2                     4.00        female
# 3                     3.88          male
# 4                     4.10        female
# ..                     ...           ...
# 130                   4.00          male
# 131                   3.97          male
# 132                   3.82        female
# 133                   4.11        female
# 134                   3.97        female
#
#                              author_genres  author_id            author_name  \
# 0                      historical-fiction,      74489    Victoria Thompson\n
# 1    literature-fiction,mystery-thrillers,     706255        Stieg Larsson\n
# 2                                 romance,    5618190  Mimi Jean Pamfiloff\n
# 3                          fiction,memoir,      37871          José Donoso\n
# 4                     young-adult,fantasy,      36122    Patricia C. Wrede\n
# ...

# %%
####################
## remove book title that is not in ASCII table
####################

# %%
book_title_index_list_to_drop = []
for i in range(len(df['book_id'])):
    if df['book_title'][i].isascii() == False:
        book_title_index_list_to_drop.append(df.index[i])
        #print(df.index[i])
        #df.drop(df.index[i])

# %%
df = df.drop(labels=book_title_index_list_to_drop, axis=0)

# %%
df.shape
# Out:
# (15835, 20)

# %%
df = df.reset_index()
del df['index']
#del df['level_0']
df.head(132)
# Out:
#      author_average_rating author_gender  \
# 0                     4.01        female
# 1                     4.15          male
# 2                     4.00        female
# 3                     3.88          male
# 4                     4.10        female
# ..                     ...           ...
# 127                   3.91        female
# 128                   4.45        female
# 129                   4.13        female
# 130                   4.00          male
# 131                   3.82        female
#
#                              author_genres  author_id            author_name  \
# 0                      historical-fiction,      74489    Victoria Thompson\n
# 1    literature-fiction,mystery-thrillers,     706255        Stieg Larsson\n
# 2                                 romance,    5618190  Mimi Jean Pamfiloff\n
# 3                          fiction,memoir,      37871          José Donoso\n
# 4                     young-adult,fantasy,      36122    Patricia C. Wrede\n
# ...

# %%
#######################################
##delete books with weried book pages
######################################

# %%
#count as book pages < 10 as invalid

# %%
# remove non_int pages
pages_index_list_to_drop_1 = []
for i in range(len(df['book_id'])):
    if df['pages'][i].isdigit() == False:
        pages_index_list_to_drop_1.append(df.index[i])
        #print(df.index[i])
        #df.drop(df.index[i])

# %%
pages_index_list_to_drop_1
# Out:
# [6244, 9981, 15708]

# %%
df = df.drop(labels=pages_index_list_to_drop_1, axis=0)

# %%
df.shape
# Out:
# (15832, 20)

# %%
df = df.reset_index()
del df['index']
#del df['level_0']
df.head(6246)
# Out:
#       author_average_rating author_gender  \
# 0                      4.01        female
# 1                      4.15          male
# 2                      4.00        female
# 3                      3.88          male
# 4                      4.10        female
# ...                     ...           ...
# 6241                   3.91          male
# 6242                   3.86          male
# 6243                   3.98          male
# 6244                   4.18        female
# 6245                   3.62        female
#
#                               author_genres  author_id  \
# 0                       historical-fiction,      74489
# 1     literature-fiction,mystery-thrillers,     706255
# 2                                  romance,    5618190
# 3                           fiction,memoir,      37871
# 4                      young-adult,fantasy,      36122
# ...                                     ...        ...
# 6241                               romance,   13536087
# ...

# %%
# remove pages < 10
pages_index_list_to_drop_2 = []
for i in range(len(df['book_id'])):
    if int(df['pages'][i]) < 10:
        pages_index_list_to_drop_2.append(df.index[i])
        #print(df.index[i])
        #df.drop(df.index[i])

# %%
pages_index_list_to_drop_2
# Out:
# [840,
#  1007,
#  1008,
#  1013,
#  1022,
#  1704,
#  1749,
#  2196,
#  2859,
#  2880,
#  3782,
#  3790,
#  4109,
#  5436,
#  6056,
#  6597,
#  7673,
#  8816,
#  9091,
#  9161,
#  9551,
#  9717,
#  9972,
#  9998,
#  11131,
#  11235,
#  11258,
#  11318,
#  12004,
#  12166,
#  12318,
#  12415,
#  14031,
#  14203,
#  15017,
#  15342,
#  15392,
#  15636,
#  15663,
#  15770]

# %%
df = df.drop(labels=pages_index_list_to_drop_2, axis=0)

# %%
df.shape
# Out:
# (15792, 20)

# %%
df = df.reset_index()
del df['index']
#del df['level_0']
df.head(841)
# Out:
#      author_average_rating author_gender  \
# 0                     4.01        female
# 1                     4.15          male
# 2                     4.00        female
# 3                     3.88          male
# 4                     4.10        female
# ..                     ...           ...
# 836                   3.91        female
# 837                   3.75        female
# 838                   4.35        female
# 839                   3.92        female
# 840                   3.82        female
#
#                               author_genres  author_id            author_name  \
# 0                       historical-fiction,      74489    Victoria Thompson\n
# 1     literature-fiction,mystery-thrillers,     706255        Stieg Larsson\n
# 2                                  romance,    5618190  Mimi Jean Pamfiloff\n
# 3                           fiction,memoir,      37871          José Donoso\n
# ...

# %%
#######################################
##delete genres that is "see top shelves"
#######################################

# %%
'see' in df['genre_1'][1]
# Out:
# False

# %%
genres_index_list_to_drop = []
for i in range(len(df['book_id'])):
    if 'See' in df['genre_1'][i] or 'See' in df['genre_2'][i]:
        genres_index_list_to_drop.append(df.index[i])
        #print(df.index[i])
        #df.drop(df.index[i])

# %%
#genres_index_list_to_drop

# %%
df = df.drop(labels=genres_index_list_to_drop, axis=0)

# %%
df.shape
# Out:
# (15380, 20)

# %%
df = df.reset_index()
del df['index']
#del df['level_0']
df.head(841)
# Out:
#      author_average_rating author_gender  \
# 0                     4.01        female
# 1                     4.15          male
# 2                     4.00        female
# 3                     3.88          male
# 4                     4.10        female
# ..                     ...           ...
# 836                   3.91        female
# 837                   3.75        female
# 838                   4.35        female
# 839                   3.92        female
# 840                   4.13          male
#
#                               author_genres  author_id            author_name  \
# 0                       historical-fiction,      74489    Victoria Thompson\n
# 1     literature-fiction,mystery-thrillers,     706255        Stieg Larsson\n
# 2                                  romance,    5618190  Mimi Jean Pamfiloff\n
# 3                           fiction,memoir,      37871          José Donoso\n
# ...

# %%
##########################################
##delete books which names are not in letters
##########################################

# %%
eng_names_index_list_to_drop = []
for i in range(len(df['book_id'])):
    if 'See' in df['genre_1'][i] or 'See' in df['genre_2'][i]:
        eng_names_index_list_to_drop.append(df.index[i])
        #print(df.index[i])
        #df.drop(df.index[i])

# %%
df['book_title'][840]
# Out:
# '\n      Liberty Belle\n'

# %%
df['book_title'][840].strip('\n').strip().replace(" ", "")
# Out:
# 'LibertyBelle'

# %%
import re
book_title_list = []
for i in range(len(df['book_title'])):
    #book_title_list.append(df['book_title'][i].strip('\n').strip().replace(" ", ""))
    book_title_list.append(re.sub(r'[^\w\s]', '',df['book_title'][i].strip('\n').strip().replace(" ", "")))
book_title_list
# Out:
# ['MurderonStMarksPlace',
#  'TheGirlwiththeDragonTattoo',
#  'TailoredforTrouble',
#  'TheObsceneBirdofNight',
#  'SorceryCeceliaorTheEnchantedChocolatePot',
#  '30DaysofNightVol1',
#  'StalkMe',
#  'BonkTheCuriousCouplingofScienceandSex',
#  'KissoftheVampire',
#  'LeavingParadise',
#  'Firefight',
#  'LokisWolves',
#  'DevilinWinter',
#  'Mockingjay',
#  'Island',
#  'DirtyRoss',
#  'Screwups',
#  'PullMeUnder',
#  'StrengthoftheMate',
#  'TequilaMockingbird',
#  'OfLastResort',
#  'SlowBurn',
#  'ComplementaryColors',
#  'MarkofCain',
#  'WoodScrewsNails',
#  'BeautyAndTheBookworm',
#  'BadInfluence',
#  'TheUnderstatementoftheYear',
#  'TheOnlyOneWhoKnows',
#  'Payoff',
#  'Reawakening',
#  'PersonalSecrets',
#  'TheHouseonHancockHill',
#  'TimberPackChronicles',
#  'RemnantACaldwellFeximalWhyborneGriffinMystery',
#  'TheRiverLeith',
#  'Turning16',
#  'ToughLove',
#  'StoriesBeneathOurSkin',
#  'BeneaththeStain',
#  'FairPlay',
#  '127AnICoSAnthology',
#  'WolfinGucciLoafers',
# ...

# %%
non_eng_book_index = []
for i in range(len(book_title_list)):
    if book_title_list[i].isalpha() == False:
        non_eng_book_index.append(i)
non_eng_book_index
# Out:
# [5,
#  36,
#  41,
#  56,
#  229,
#  230,
#  361,
#  418,
#  422,
#  500,
#  504,
#  505,
#  509,
#  510,
#  512,
#  515,
#  517,
#  522,
#  527,
#  532,
#  534,
#  536,
#  538,
#  544,
#  546,
#  551,
#  553,
#  556,
#  557,
#  558,
#  659,
#  828,
#  856,
#  872,
#  904,
#  938,
#  939,
#  949,
#  1009,
#  1013,
#  1017,
#  1033,
#  1043,
#  1070,
#  1102,
#  1206,
#  1226,
#  1268,
#  1296,
#  1315,
#  1333,
#  1389,
#  1430,
#  1509,
#  1558,
#  1560,
#  1580,
#  1616,
#  1617,
#  1644,
#  1683,
#  1703,
#  1727,
#  1742,
#  1763,
#  1790,
#  1852,
#  1953,
#  1979,
#  2028,
#  2076,
#  2127,
#  2174,
#  2222,
#  2288,
#  2295,
#  2298,
#  2299,
#  2301,
#  2306,
#  2331,
#  2383,
#  2404,
#  2501,
#  2533,
#  2546,
#  2556,
#  2576,
#  2717,
#  2754,
#  2831,
#  2836,
#  2874,
#  2880,
#  2895,
#  2902,
#  3084,
#  3124,
#  3139,
#  3148,
#  3172,
#  3179,
#  3251,
#  3324,
#  3325,
#  3326,
#  3327,
#  3328,
#  3329,
#  3330,
#  3331,
#  3332,
#  3333,
#  3334,
#  3335,
# ...

# %%
df = df.drop(labels=non_eng_book_index, axis=0)

# %%
df.shape
# Out:
# (14717, 20)

# %%
df = df.reset_index()
del df['index']
#del df['level_0']
df.head(841)
# Out:
#      author_average_rating author_gender  \
# 0                     4.01        female
# 1                     4.15          male
# 2                     4.00        female
# 3                     3.88          male
# 4                     4.10        female
# ..                     ...           ...
# 836                   4.16        female
# 837                   3.82        female
# 838                   3.99          male
# 839                   4.05          male
# 840                   3.94          male
#
#                                          author_genres  author_id  \
# 0                                  historical-fiction,      74489
# 1                literature-fiction,mystery-thrillers,     706255
# 2                                             romance,    5618190
# 3                                      fiction,memoir,      37871
# 4                                 young-adult,fantasy,      36122
# ..                                                 ...        ...
# ...

# %%
################################
###make sure average rate between 0-5
################################

# %%
df['author_average_rating'][0]<5.0
# Out:
# True

# %%
df['author_average_rating'][1682]
# Out:
# 5.0

# %%
rate_index_to_delete = []
for i in range(len(df['author_average_rating'])):
    if not (df['author_average_rating'][i] <= 5.0 and df['author_average_rating'][i] >= 0):
        rate_index_to_delete.append(i)
rate_index_to_delete
# Out:
# []

# %%
######################
##keep only the dates in years
######################

# %%
a = []
for i in range(len(df['publish_date'])):
    #for x in range(len(df['publish_date'][i])):
    a.append(df['publish_date'][i])
a
# Out:
# ['2000',
#  'August 2005',
#  '2016',
#  '1970',
#  'April 15th 1988',
#  'August 20th 2012',
#  '2008',
#  'January 1st 1993',
#  'April 1st 2007',
#  '2015',
#  '2013',
#  '2006',
#  '2010',
#  '1962',
#  'April 7th 2014',
#  'March 6th 2014',
#  '2014',
#  '2014',
#  'June 26th 2014',
#  'July 24th 2013',
#  '2014',
#  'June 19th 2014',
#  '2014',
#  'April 22nd 2014',
#  '2014',
#  '2014',
#  'September 29th 2014',
#  '2014',
#  'February 1st 2014',
#  'January 16th 2014',
#  'February 10th 2014',
#  'February 6th 2014',
#  'January 1st 2011',
#  '2014',
#  '2014',
#  '2014',
#  '2014',
#  'August 29th 2014',
#  '2014',
#  'April 15th 2014',
#  'September 26th 2014',
#  '2014',
#  '2014',
#  '2014',
#  'April 17th 2014',
#  'January 17th 2014',
#  'April 27th 2014',
#  'August 31st 2014',
#  'February 23rd 2014',
#  'January 21st 2014',
#  'September 14th 2014',
#  'April 10th 2014',
#  'May 2014',
#  '2014',
#  '2014',
#  '2014',
#  'February 18th 2014',
#  '2014',
# ...

# %%
a[0][-4:]
# Out:
# '2000'

# %%
only_year = []
for x in a:
    #b = x[-4:]
    only_year.append(str(x)[-4:])
only_year
# Out:
# ['2000',
#  '2005',
#  '2016',
#  '1970',
#  '1988',
#  '2012',
#  '2008',
#  '1993',
#  '2007',
#  '2015',
#  '2013',
#  '2006',
#  '2010',
#  '1962',
#  '2014',
#  '2014',
#  '2014',
#  '2014',
#  '2014',
#  '2013',
#  '2014',
#  '2014',
#  '2014',
#  '2014',
#  '2014',
#  '2014',
#  '2014',
#  '2014',
#  '2014',
#  '2014',
#  '2014',
#  '2014',
#  '2011',
#  '2014',
#  '2014',
#  '2014',
#  '2014',
#  '2014',
#  '2014',
#  '2014',
#  '2014',
#  '2014',
#  '2014',
#  '2014',
#  '2014',
#  '2014',
#  '2014',
#  '2014',
#  '2014',
#  '2014',
#  '2014',
#  '2014',
#  '2014',
#  '2014',
#  '2014',
#  '2014',
#  '2014',
#  '2014',
#  '2014',
#  '2014',
#  '2014',
#  '2014',
#  '2014',
#  '2014',
#  '2014',
#  '2014',
#  '2014',
#  '2014',
#  '2014',
#  '2014',
#  '2014',
#  '2014',
#  '2014',
#  '2010',
#  '1987',
#  '2004',
#  '1961',
#  '2010',
#  '1967',
#  '1952',
#  '1977',
#  '1949',
#  '1963',
#  '2006',
#  '1977',
#  '2009',
#  '1995',
#  '2012',
#  '2014',
#  '1982',
# ...

# %%
#drop original column
df.drop(['publish_date'], axis=1)
# Out:
#        author_average_rating author_gender  \
# 0                       4.01        female
# 1                       4.15          male
# 2                       4.00        female
# 3                       3.88          male
# 4                       4.10        female
# ...                      ...           ...
# 14712                   4.08        female
# 14713                   4.09        female
# 14714                   3.94        female
# 14715                   4.00        female
# 14716                   4.20        female
#
#                                author_genres  author_id  \
# 0                        historical-fiction,      74489
# 1      literature-fiction,mystery-thrillers,     706255
# 2                                   romance,    5618190
# 3                            fiction,memoir,      37871
# 4                       young-adult,fantasy,      36122
# ...                                      ...        ...
# ...

# %%
#add new columns with only years
df['publish_date'] = only_year
df.head(1683)
# Out:
#       author_average_rating author_gender  \
# 0                      4.01        female
# 1                      4.15          male
# 2                      4.00        female
# 3                      3.88          male
# 4                      4.10        female
# ...                     ...           ...
# 1678                   4.05        female
# 1679                   3.93        female
# 1680                   3.60        female
# 1681                   3.79          male
# 1682                   5.00          male
#
#                               author_genres  author_id            author_name  \
# 0                       historical-fiction,      74489    Victoria Thompson\n
# 1     literature-fiction,mystery-thrillers,     706255        Stieg Larsson\n
# 2                                  romance,    5618190  Mimi Jean Pamfiloff\n
# 3                           fiction,memoir,      37871          José Donoso\n
# ...

# %%
# delete non_int dates

# %%
df['publish_date'][1]. isdecimal()
# Out:
# True

# %%
df['publish_date'][1197]
# Out:
# '4th'

# %%
non_int_date_index = []
for i in range(len(df['publish_date'])):
    if df['publish_date'][i]. isdecimal() == False:
            non_int_date_index.append(i)
            #non_int_date_index.append(df['publish_date'][i])
non_int_date_index
# Out:
# [115,
#  175,
#  386,
#  443,
#  447,
#  574,
#  709,
#  799,
#  805,
#  820,
#  921,
#  930,
#  964,
#  968,
#  975,
#  1051,
#  1098,
#  1162,
#  1184,
#  1185,
#  1186,
#  1187,
#  1188,
#  1189,
#  1190,
#  1191,
#  1192,
#  1195,
#  1196,
#  1197,
#  1199,
#  1200,
#  1201,
#  1202,
#  1206,
#  1218,
#  1337,
#  1339,
#  1480,
#  1485,
#  1539,
#  1681,
#  1682,
#  1683,
#  1684,
#  1685,
#  1719,
#  1824,
#  1835,
#  1841,
#  1864,
#  1906,
#  1920,
#  1996,
#  2008,
#  2095,
#  2100,
#  2101,
#  2110,
#  2117,
#  2119,
#  2143,
#  2167,
#  2197,
#  2217,
#  2300,
#  2312,
#  2329,
#  2379,
#  2632,
#  2648,
#  2724,
#  2772,
#  2773,
#  2853,
#  2865,
#  2888,
#  2989,
#  3033,
#  3058,
#  3101,
#  3186,
#  3190,
#  3215,
#  3234,
#  3258,
#  3266,
#  3270,
#  3300,
#  3337,
#  3410,
#  3461,
#  3547,
#  3606,
#  3625,
#  3646,
#  3842,
#  3886,
#  3946,
#  3975,
#  3983,
#  4035,
#  4118,
#  4146,
#  4159,
#  4240,
#  4356,
#  4481,
#  4528,
#  4593,
#  4610,
#  4612,
# ...

# %%
df = df.drop(labels=non_int_date_index, axis=0)

# %%
df.head(116)
# Out:
#      author_average_rating author_gender  \
# 0                     4.01        female
# 1                     4.15          male
# 2                     4.00        female
# 3                     3.88          male
# 4                     4.10        female
# ..                     ...           ...
# 111                   3.94          male
# 112                   4.06          male
# 113                   3.83        female
# 114                   4.21          male
# 116                   3.82          male
#
#                                          author_genres  author_id  \
# 0                                  historical-fiction,      74489
# 1                literature-fiction,mystery-thrillers,     706255
# 2                                             romance,    5618190
# 3                                      fiction,memoir,      37871
# 4                                 young-adult,fantasy,      36122
# ..                                                 ...        ...
# ...

# %%
df.shape
# Out:
# (14296, 20)

# %%
df = df.reset_index()
del df['index']
#del df['level_0']

# %%
##########################
##make sure female and male
##########################

# %%
correct_gender_index = []
a = 0
for i in range(len(df['author_gender'])):
    if not (df['author_gender'][i] == 'female' or 'male'):
            correct_gender_index.append(i)
            a+=1
            #non_int_date_index.append(df['publish_date'][i])
correct_gender_index
a
# Out:
# 0

# %%
df['birthplace'].replace(r'\s+|\\n', ' ', regex=True, inplace=True)
df['book_title'].replace(r'\s+|\\n', ' ', regex=True, inplace=True)
df['author_name'].replace(r'\s+|\\n', ' ', regex=True, inplace=True)
df['birthplace'] = df['birthplace'].str.strip()
df['book_title'] = df['book_title'].str.strip()
df['author_genres'] = df['author_genres'].str.replace(',+$', '')
df['publish_date'] = df['publish_date'].replace(r'^\s*$', np.nan, regex=True)
df['publish_date'] = df['publish_date'].str[-4:]
df['publish_date'] = df['publish_date'].replace('by', np.nan, regex=True)
df['birthplace']=df['birthplace'].replace(r'^\s*$', np.nan, regex=True)
df['publish_date'] = pd.to_numeric(df['publish_date'], errors='coerce')
df['book_id'] = df['book_id'].str.extract('(\d+)', expand=False)
df['book_id'] = df['book_id'].astype(int)
df['pages'] = df['pages'].str.extract('(\d+)', expand=False)
df['pages'] = df['pages'].astype(int)
# Out:
# /var/folders/x5/_dbmbfq14jlczb3f5l2vc35r0000gn/T/ipykernel_11963/3043886896.py:6: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['author_genres'] = df['author_genres'].str.replace(',+$', '')

# %%
holder = []
for i in range(len(df)):
    holder.append(df["genre_1"][i])
    holder.append(df["genre_2"][i])
#     print(holder)
    holder.sort()
#     print(holder)
    df["genre_1"][i] = holder[0]
    df["genre_2"][i] = holder[1]
    holder = []
# Out:
# /var/folders/x5/_dbmbfq14jlczb3f5l2vc35r0000gn/T/ipykernel_11963/1238431123.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["genre_1"][i] = holder[0]
# /var/folders/x5/_dbmbfq14jlczb3f5l2vc35r0000gn/T/ipykernel_11963/1238431123.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["genre_2"][i] = holder[1]

# %%
df.loc[111]
# Out:
# author_average_rating                                            3.94
# author_gender                                                    male
# author_genres                     literature-fiction,political-satire
# author_id                                                       43298
# author_name                                         Yevgeny Zamyatin
# author_page_url                   /author/show/43298.Yevgeny_Zamyatin
# author_rating_count                                             57629
# author_review_count                                              3642
# birthplace                                         Russian Federation
# book_average_rating                                              3.94
# book_fullurl             https://www.goodreads.com/book/show/76171.We
# book_id                                                         76171
# book_title                                                         We
# ...

# %%
df.to_csv('/Users/zhenweiliu/Desktop/ECE229-Group6/cleaned_book_data.csv')
